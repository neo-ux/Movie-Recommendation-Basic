# %%
# Data handling
import pandas as pd
import numpy as np

# NLP & similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Optional: For displaying results
import warnings
warnings.filterwarnings('ignore')

# %%
# Load your movies dataset (example: movies.csv)
movies = pd.read_csv('movies.csv')

# Preview the dataset
movies.head()
# Out:
#      title    genre           director  \
# 0  Movie 1   Action  Christopher Nolan
# 1  Movie 2   Comedy   Steven Spielberg
# 2  Movie 3    Drama  Quentin Tarantino
# 3  Movie 4  Romance    Martin Scorsese
# 4  Movie 5   Sci-Fi      James Cameron
#
#                                              cast  \
# 0                    Leonardo DiCaprio; Brad Pitt
# 1                   Tom Hanks; Scarlett Johansson
# 2                       Brad Pitt; Morgan Freeman
# 3                     Angelina Jolie; Johnny Depp
# 4  Chris Hemsworth; Anne Hathaway; Christian Bale
#
#                                             overview
# 0                An epic story of love and betrayal.
# 1            A comedic series of unfortunate events.
# 2  A drama exploring human emotions and relations...
# 3  A story about friendship and overcoming challe...
# 4         An intense journey through time and space.

# %%
# Fill missing values with empty string
for feature in ['genre', 'director', 'cast', 'overview']:
    movies[feature] = movies[feature].fillna('')

# Combine features into a single string for content-based recommendation
def combine_features(row):
    return row['genre'] + " " + row['director'] + " " + row['cast'] + " " + row['overview']

movies['combined_features'] = movies.apply(combine_features, axis=1)

# %%
# Convert text to TF-IDF vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(movies['combined_features'])

# Compute cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# Helper function to get movie index
def get_index(title):
    return movies[movies.title == title].index[0]

# Recommendation function
def recommend_movies(movie_title, num_recommendations=5):
    movie_index = get_index(movie_title)
    similar_movies = list(enumerate(cosine_sim[movie_index]))
    # Sort movies based on similarity score
    sorted_movies = sorted(similar_movies, key=lambda x: x[1], reverse=True)[1:num_recommendations+1]
    
    recommended_titles = [movies.iloc[i[0]].title for i in sorted_movies]
    return recommended_titles

# %%
recommend_movies('Movie 1', num_recommendations=5)
# Out:
# ['Movie 41', 'Movie 31', 'Movie 21', 'Movie 11', 'Movie 49']

# %%
print(movies.head(20))
# Out:
#        title      genre           director  \
# 0    Movie 1     Action  Christopher Nolan
# 1    Movie 2     Comedy   Steven Spielberg
# 2    Movie 3      Drama  Quentin Tarantino
# 3    Movie 4    Romance    Martin Scorsese
# 4    Movie 5     Sci-Fi      James Cameron
# 5    Movie 6     Horror       Ridley Scott
# 6    Movie 7   Thriller      Peter Jackson
# 7    Movie 8      Crime      David Fincher
# 8    Movie 9    Fantasy         Tim Burton
# 9   Movie 10  Adventure   Alfred Hitchcock
# 10  Movie 11     Action  Christopher Nolan
# 11  Movie 12     Comedy   Steven Spielberg
# 12  Movie 13      Drama  Quentin Tarantino
# 13  Movie 14    Romance    Martin Scorsese
# 14  Movie 15     Sci-Fi      James Cameron
# 15  Movie 16     Horror       Ridley Scott
# 16  Movie 17   Thriller      Peter Jackson
# 17  Movie 18      Crime      David Fincher
# 18  Movie 19    Fantasy         Tim Burton
# 19  Movie 20  Adventure   Alfred Hitchcock
#
#                                                  cast  \
# 0                        Leonardo DiCaprio; Brad Pitt
# 1                       Tom Hanks; Scarlett Johansson
# 2                           Brad Pitt; Morgan Freeman
# 3                         Angelina Jolie; Johnny Depp
# 4      Chris Hemsworth; Anne Hathaway; Christian Bale
# 5       Natalie Portman; Leonardo DiCaprio; Tom Hanks
# 6    Robert Downey Jr.; Brad Pitt; Scarlett Johansson
# 7                   Leonardo DiCaprio; Angelina Jolie
# 8          Tom Hanks; Christian Bale; Natalie Portman
# 9        Johnny Depp; Morgan Freeman; Chris Hemsworth
# 10                   Leonardo DiCaprio; Anne Hathaway
# 11                          Brad Pitt; Angelina Jolie
# 12                      Tom Hanks; Scarlett Johansson
# 13                 Chris Hemsworth; Robert Downey Jr.
# 14    Leonardo DiCaprio; Johnny Depp; Natalie Portman
# 15                          Brad Pitt; Christian Bale
# 16                      Scarlett Johansson; Tom Hanks
# 17                    Chris Hemsworth; Angelina Jolie
# 18  Leonardo DiCaprio; Robert Downey Jr.; Natalie ...
# 19              Tom Hanks; Brad Pitt; Chris Hemsworth
#
#                                              overview  \
# 0                 An epic story of love and betrayal.
# 1             A comedic series of unfortunate events.
# 2   A drama exploring human emotions and relations...
# 3   A story about friendship and overcoming challe...
# 4          An intense journey through time and space.
# 5   A suspenseful story that keeps you on the edge...
# 6            A gripping tale of crime and redemption.
# 7       A fight against evil forces to save humanity.
# 8   A fantastical world filled with magic and danger.
# 9   A thrilling adventure that tests the limits of...
# 10                An epic story of love and betrayal.
# 11            A comedic series of unfortunate events.
# 12  A drama exploring human emotions and relations...
# 13  A story about friendship and overcoming challe...
# 14         An intense journey through time and space.
# 15  A suspenseful story that keeps you on the edge...
# 16           A gripping tale of crime and redemption.
# 17      A fight against evil forces to save humanity.
# 18  A fantastical world filled with magic and danger.
# 19  A thrilling adventure that tests the limits of...
#
#                                     combined_features
# 0   Action Christopher Nolan Leonardo DiCaprio; Br...
# 1   Comedy Steven Spielberg Tom Hanks; Scarlett Jo...
# 2   Drama Quentin Tarantino Brad Pitt; Morgan Free...
# 3   Romance Martin Scorsese Angelina Jolie; Johnny...
# 4   Sci-Fi James Cameron Chris Hemsworth; Anne Hat...
# 5   Horror Ridley Scott Natalie Portman; Leonardo ...
# 6   Thriller Peter Jackson Robert Downey Jr.; Brad...
# 7   Crime David Fincher Leonardo DiCaprio; Angelin...
# 8   Fantasy Tim Burton Tom Hanks; Christian Bale; ...
# 9   Adventure Alfred Hitchcock Johnny Depp; Morgan...
# 10  Action Christopher Nolan Leonardo DiCaprio; An...
# 11  Comedy Steven Spielberg Brad Pitt; Angelina Jo...
# 12  Drama Quentin Tarantino Tom Hanks; Scarlett Jo...
# 13  Romance Martin Scorsese Chris Hemsworth; Rober...
# 14  Sci-Fi James Cameron Leonardo DiCaprio; Johnny...
# 15  Horror Ridley Scott Brad Pitt; Christian Bale ...
# 16  Thriller Peter Jackson Scarlett Johansson; Tom...
# 17  Crime David Fincher Chris Hemsworth; Angelina ...
# 18  Fantasy Tim Burton Leonardo DiCaprio; Robert D...
# 19  Adventure Alfred Hitchcock Tom Hanks; Brad Pit...
